# %% [markdown]
# <a href="https://colab.research.google.com/github/asengardeon/aprendizado_de_maquina/blob/master/trabalho_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/resulta_pedidos_541-29-10-2020.CSV", sep=";")

# %%
df.head()
# Out:
#                               chave_unica  ... envio_promax.resultadoHercules.listaPedidos.0.listaItens.23.precoPlanejado
# 0  05412909202029092020210000000003223001  ...                                                NaN
# 1  05412909202029092020210000000020065001  ...                                                NaN
# 2  05412909202029092020210000000020065002  ...                                                NaN
# 3  05412909202029092020210000000020065003  ...                                                NaN
# 4  05412909202029092020210000000021187001  ...                                                NaN
#
# [5 rows x 303 columns]
